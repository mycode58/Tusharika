# %%
import sys
import subprocess
import pkgutil
if pkgutil.find_loader('yfinance') is None:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', 'yfinance'])

import yfinance as yf
import pandas as pd

ticker = "AAPL"

data = yf.download(ticker, period="3mo", interval="1d")

close_prices = data['Close']

delta = close_prices.diff()

gain = delta.where(delta > 0, 0)
loss = -delta.where(delta < 0, 0)

avg_gain = gain.rolling(window=14).mean()
avg_loss = loss.rolling(window=14).mean()

rs = avg_gain / avg_loss

rsi = 100 - (100 / (1 + rs))

# FIX HERE
latest_rsi = rsi.dropna().iloc[-1].item()

print(latest_rsi)
# Out:
# /tmp/ipykernel_7536/3565421479.py:4: DeprecationWarning: 'pkgutil.find_loader' is deprecated and slated for removal in Python 3.14; use importlib.util.find_spec() instead
#   if pkgutil.find_loader('yfinance') is None:
# [*********************100%***********************]  1 of 1 completed
# 83.88339060759928
